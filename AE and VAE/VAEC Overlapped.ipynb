# %%
from keras.models import Sequential 
from keras.layers import Dense,Conv2D,MaxPooling2D,UpSampling2D
from keras import Input, Model
from keras.datasets import mnist
from keras import backend as k
from keras.layers import Lambda
from tensorflow.keras.metrics import binary_crossentropy
import keras
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout
import pandas as pd
import random
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import itertools

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
data = pd.read_csv('Data.csv')

X = data.drop(['label','Label'], axis = 1)
y = data['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=10)

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.
X_train = X_train.values.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.values.reshape((len(X_test), np.prod(X_test.shape[1:])))
print(X_train.shape)
print(X_test.shape)
# Out:
# (17132, 784)
# (4284, 784)

# %%
def sampling(args):
    mu, log_var = args
    eps = k.random_normal(shape=(keras.backend.shape(mu)[0], latent_dim), mean=0., stddev=1.0)
    return mu + k.exp(log_var) * eps

# %%
batch_size, n_epoch = 100, 150
latent_dim = 2

input_data = Input(shape=(X_train[0].shape))
X = Dense(200, activation='relu')(input_data)
X= Dense(100, activation='relu')(X)
X = Dense(30, activation='relu')(X)

mu = Dense(latent_dim)(X)
log_var = Dense(latent_dim)(X)

z = Lambda(sampling)([mu, log_var])

encoder = Model(input_data, z, name='Encoder')
encoder.summary()
# Out:
# Model: "Encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 200)          157000      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 100)          20100       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 30)           3030        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  lambda (Lambda)                (None, 2)            0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
# ==================================================================================================
# Total params: 180,254
# Trainable params: 180,254
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
z_decoder1 = Dense(30, activation='relu')
z_decoder2 = Dense(100, activation='relu')
z_decoder3 = Dense(200, activation='relu')
y_decoder = Dense((X_train[0].shape[0]), activation='sigmoid')

z_decoded = z_decoder1(z)
z_decoded = z_decoder2(z_decoded)
z_decoded = z_decoder3(z_decoded)
y = y_decoder(z_decoded)

decoder = Model(z, y, name='Decoder')
decoder.summary()
# Out:
# Model: "Decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_5 (Dense)             (None, 30)                90
#
#  dense_6 (Dense)             (None, 100)               3100
#
#  dense_7 (Dense)             (None, 200)               20200
#
#  dense_8 (Dense)             (None, 784)               157584
#
# =================================================================
# Total params: 180,974
# Trainable params: 180,974
# Non-trainable params: 0
# _________________________________________________________________

# %%
reconstruction_loss = binary_crossentropy(input_data, y) * X_train[0].shape
kl_loss = 0.5 * k.sum(k.square(mu) + k.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + kl_loss

vae = Model(input_data, y, name='VAE')
vae.add_loss(vae_loss)

vae.summary()
# Out:
# Model: "VAE"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 200)          157000      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 100)          20100       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 30)           3030        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  lambda (Lambda)                (None, 2)            0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 30)           90          ['lambda[0][0]']
#
#  dense_6 (Dense)                (None, 100)          3100        ['dense_5[0][0]']
#
#  dense_7 (Dense)                (None, 200)          20200       ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 784)          157584      ['dense_7[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['dense_3[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 2)            0           ['dense_4[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.square[0][0]',
#  da)                                                              'tf.math.exp[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 784)          0           ['input_1[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (None, 784)         0           ['dense_8[0][0]']
#  da)
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.__operators__.add[0][0]',
#                                                                   'dense_4[0][0]']
#
#  tf.keras.backend.binary_crosse  (None, 784)         0           ['tf.cast[0][0]',
#  ntropy (TFOpLambda)                                              'tf.convert_to_tensor[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (None,)             0           ['tf.keras.backend.binary_crossen
#  a)                                                              tropy[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (None,)              0           ['tf.math.reduce_mean[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (None,)             0           ['tf.math.multiply[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  add_loss (AddLoss)             (None,)              0           ['tf.__operators__.add_1[0][0]']
#
# ==================================================================================================
# Total params: 361,228
# Trainable params: 361,228
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.compile(optimizer='rmsprop')
history = vae.fit(X_train, shuffle=True, epochs=14, batch_size=batch_size, validation_data=(X_train, None), verbose=1)
# Out:
# Epoch 1/14
# 172/172 [==============================] - 3s 11ms/step - loss: 215.3873 - val_loss: 190.8658
# Epoch 2/14
# 172/172 [==============================] - 2s 14ms/step - loss: 180.7224 - val_loss: 169.3895
# Epoch 3/14
# 172/172 [==============================] - 2s 13ms/step - loss: 165.6526 - val_loss: 160.4345
# Epoch 4/14
# 172/172 [==============================] - 2s 12ms/step - loss: 158.7065 - val_loss: 155.1973
# Epoch 5/14
# 172/172 [==============================] - 2s 13ms/step - loss: 154.0056 - val_loss: 151.2801
# Epoch 6/14
# 172/172 [==============================] - 2s 12ms/step - loss: 150.3946 - val_loss: 148.0933
# Epoch 7/14
# 172/172 [==============================] - 2s 13ms/step - loss: 147.5157 - val_loss: 145.3650
# Epoch 8/14
# 172/172 [==============================] - 2s 13ms/step - loss: 145.4775 - val_loss: 144.4287
# Epoch 9/14
# 172/172 [==============================] - 2s 13ms/step - loss: 144.0150 - val_loss: 142.4220
# Epoch 10/14
# 172/172 [==============================] - 2s 13ms/step - loss: 142.7116 - val_loss: 141.4031
# Epoch 11/14
# 172/172 [==============================] - 2s 13ms/step - loss: 141.8033 - val_loss: 140.6877
# Epoch 12/14
# 172/172 [==============================] - 2s 12ms/step - loss: 140.7695 - val_loss: 139.6253
# Epoch 13/14
# 172/172 [==============================] - 2s 13ms/step - loss: 139.9790 - val_loss: 138.6178
# Epoch 14/14
# 172/172 [==============================] - 2s 13ms/step - loss: 139.0156 - val_loss: 137.4869

# %%
x_te_latent = encoder.predict(X_test, batch_size=256)
plt.figure(figsize=(6, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], s=20, alpha=0.8, cmap='Set1', c=y_test[0:X_test.shape[0]])
plt.axis('off')   
plt.show()
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
encoder.trainable = False

# %%
cls1 = Dense(3, activation='relu')
cls2 = Dense(4, activation='relu')
cls3 = Dense(5, activation='softmax')

CL1 = cls1(z)
CL2 = cls2(CL1)
CL3 = cls3(CL2)

# %%
vaec = Model(input_data, CL3, name='VAEClassifier')
vaec.summary()
# Out:
# Model: "VAEClassifier"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 200)          157000      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 100)          20100       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 30)           3030        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  lambda (Lambda)                (None, 2)            0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_9 (Dense)                (None, 3)            9           ['lambda[0][0]']
#
#  dense_10 (Dense)               (None, 4)            16          ['dense_9[0][0]']
#
#  dense_11 (Dense)               (None, 5)            25          ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 180,304
# Trainable params: 50
# Non-trainable params: 180,254
# __________________________________________________________________________________________________

# %%
lbl = LabelEncoder()
y_train = lbl.fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = lbl.fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam()

# Configuring the model for training
vaec.compile(optimizer=opt, loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history_vaec = vaec.fit(X_train,y_train,epochs=50,batch_size=5,validation_split=0.2)
# Out:
# Epoch 1/50
# 2741/2741 [==============================] - 10s 3ms/step - loss: 0.9172 - accuracy: 0.5879 - val_loss: 0.5915 - val_accuracy: 0.8112
# Epoch 2/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.5283 - accuracy: 0.7903 - val_loss: 0.4644 - val_accuracy: 0.8255
# Epoch 3/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.4558 - accuracy: 0.8110 - val_loss: 0.4228 - val_accuracy: 0.8270
# Epoch 4/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.4300 - accuracy: 0.8128 - val_loss: 0.4031 - val_accuracy: 0.8392
# Epoch 5/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.4166 - accuracy: 0.8209 - val_loss: 0.3914 - val_accuracy: 0.8407
# Epoch 6/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.4087 - accuracy: 0.8159 - val_loss: 0.3859 - val_accuracy: 0.8404
# Epoch 7/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.4029 - accuracy: 0.8230 - val_loss: 0.3792 - val_accuracy: 0.8389
# Epoch 8/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3985 - accuracy: 0.8259 - val_loss: 0.3767 - val_accuracy: 0.8421
# Epoch 9/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3949 - accuracy: 0.8286 - val_loss: 0.3730 - val_accuracy: 0.8375
# Epoch 10/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3945 - accuracy: 0.8271 - val_loss: 0.3672 - val_accuracy: 0.8401
# Epoch 11/50
# 2741/2741 [==============================] - 11s 4ms/step - loss: 0.3916 - accuracy: 0.8301 - val_loss: 0.3666 - val_accuracy: 0.8451
# Epoch 12/50
# 2741/2741 [==============================] - 11s 4ms/step - loss: 0.3890 - accuracy: 0.8282 - val_loss: 0.3663 - val_accuracy: 0.8316
# Epoch 13/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3874 - accuracy: 0.8283 - val_loss: 0.3625 - val_accuracy: 0.8375
# Epoch 14/50
# 2741/2741 [==============================] - 11s 4ms/step - loss: 0.3865 - accuracy: 0.8266 - val_loss: 0.3641 - val_accuracy: 0.8468
# Epoch 15/50
# 2741/2741 [==============================] - 11s 4ms/step - loss: 0.3850 - accuracy: 0.8293 - val_loss: 0.3587 - val_accuracy: 0.8448
# Epoch 16/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3855 - accuracy: 0.8290 - val_loss: 0.3613 - val_accuracy: 0.8270
# Epoch 17/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3862 - accuracy: 0.8259 - val_loss: 0.3607 - val_accuracy: 0.8401
# Epoch 18/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3832 - accuracy: 0.8279 - val_loss: 0.3581 - val_accuracy: 0.8351
# Epoch 19/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3841 - accuracy: 0.8276 - val_loss: 0.3597 - val_accuracy: 0.8410
# Epoch 20/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3826 - accuracy: 0.8268 - val_loss: 0.3574 - val_accuracy: 0.8185
# Epoch 21/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3806 - accuracy: 0.8239 - val_loss: 0.3589 - val_accuracy: 0.8395
# Epoch 22/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3809 - accuracy: 0.8260 - val_loss: 0.3556 - val_accuracy: 0.8439
# Epoch 23/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3810 - accuracy: 0.8252 - val_loss: 0.3554 - val_accuracy: 0.8357
# Epoch 24/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3811 - accuracy: 0.8256 - val_loss: 0.3533 - val_accuracy: 0.8389
# Epoch 25/50
# 2741/2741 [==============================] - 10s 4ms/step - loss: 0.3796 - accuracy: 0.8225 - val_loss: 0.3533 - val_accuracy: 0.8351
# Epoch 26/50
# 2741/2741 [==============================] - 11s 4ms/step - loss: 0.3807 - accuracy: 0.8267 - val_loss: 0.3556 - val_accuracy: 0.8310
# Epoch 27/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3810 - accuracy: 0.8270 - val_loss: 0.3545 - val_accuracy: 0.8427
# Epoch 28/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3807 - accuracy: 0.8243 - val_loss: 0.3573 - val_accuracy: 0.8240
# Epoch 29/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3798 - accuracy: 0.8250 - val_loss: 0.3549 - val_accuracy: 0.8322
# Epoch 30/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3800 - accuracy: 0.8215 - val_loss: 0.3570 - val_accuracy: 0.8404
# Epoch 31/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3783 - accuracy: 0.8217 - val_loss: 0.3554 - val_accuracy: 0.8421
# Epoch 32/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3787 - accuracy: 0.8257 - val_loss: 0.3482 - val_accuracy: 0.8348
# Epoch 33/50
# 2741/2741 [==============================] - 10s 4ms/step - loss: 0.3794 - accuracy: 0.8216 - val_loss: 0.3548 - val_accuracy: 0.8223
# Epoch 34/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3765 - accuracy: 0.8177 - val_loss: 0.3490 - val_accuracy: 0.8453
# Epoch 35/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3795 - accuracy: 0.8258 - val_loss: 0.3547 - val_accuracy: 0.8343
# Epoch 36/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3783 - accuracy: 0.8224 - val_loss: 0.3476 - val_accuracy: 0.8430
# Epoch 37/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3775 - accuracy: 0.8223 - val_loss: 0.3539 - val_accuracy: 0.8389
# Epoch 38/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3778 - accuracy: 0.8191 - val_loss: 0.3515 - val_accuracy: 0.8270
# Epoch 39/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3775 - accuracy: 0.8214 - val_loss: 0.3547 - val_accuracy: 0.8296
# Epoch 40/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3747 - accuracy: 0.8216 - val_loss: 0.3541 - val_accuracy: 0.8264
# Epoch 41/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3790 - accuracy: 0.8211 - val_loss: 0.3527 - val_accuracy: 0.8328
# Epoch 42/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3769 - accuracy: 0.8247 - val_loss: 0.3533 - val_accuracy: 0.8313
# Epoch 43/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3769 - accuracy: 0.8220 - val_loss: 0.3539 - val_accuracy: 0.8357
# Epoch 44/50
# 2741/2741 [==============================] - 11s 4ms/step - loss: 0.3755 - accuracy: 0.8235 - val_loss: 0.3551 - val_accuracy: 0.8229
# Epoch 45/50
# 2741/2741 [==============================] - 10s 4ms/step - loss: 0.3772 - accuracy: 0.8204 - val_loss: 0.3546 - val_accuracy: 0.8351
# Epoch 46/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3775 - accuracy: 0.8220 - val_loss: 0.3565 - val_accuracy: 0.8197
# Epoch 47/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3794 - accuracy: 0.8221 - val_loss: 0.3545 - val_accuracy: 0.8328
# Epoch 48/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3767 - accuracy: 0.8211 - val_loss: 0.3541 - val_accuracy: 0.8258
# Epoch 49/50
# 2741/2741 [==============================] - 9s 3ms/step - loss: 0.3776 - accuracy: 0.8194 - val_loss: 0.3567 - val_accuracy: 0.8191
# Epoch 50/50
# 2741/2741 [==============================] - 8s 3ms/step - loss: 0.3747 - accuracy: 0.8217 - val_loss: 0.3565 - val_accuracy: 0.8328

# %%
plt.plot(np.array((history_vaec.history)['accuracy']),'-o')
plt.plot(np.array((history_vaec.history)['val_accuracy']),'-o')
plt.title("Epochs Vs Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(['accuracy','val_accuracy'])
plt.show()

# %%
plt.plot(np.array((history_vaec.history)['loss']),'-o')
plt.plot(np.array((history_vaec.history)['val_loss']),'-o')
plt.title("Epochs Vs Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['loss','val_loss'])
plt.show()

# %%
predictions = vaec.predict(X_test)
# Out:
# 134/134 [==============================] - 0s 2ms/step

# %%
test_loss, test_acc = vaec.evaluate(X_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 134/134 [==============================] - 0s 3ms/step - loss: 0.3585 - accuracy: 0.8231
# Test loss: 0.3584994971752167
# Test accuracy: 0.823062539100647

# %%
y_pred = [np.argmax(np.round(predictions[i])) for i in range(len(X_test))]
y_true = [np.argmax(y_test[i]) for i in range(len(X_test))]

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.BuPu):
    
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
cm = confusion_matrix(y_true,y_pred)
cm_plot = plot_confusion_matrix(cm,classes=[str(i) for i in set(data['Label'])])
